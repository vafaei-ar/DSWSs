# %%
# %matplotlib inline

import io
import numpy as np
import cv2
import base64
import cv2 # OpenCV-Python
import matplotlib.pyplot as plt

# %%
import numpy as np
import cv2

cap = cv2.VideoCapture(0)

while(True):
    # Capture frame-by-frame
    ret, frame = cap.read()
    # Our operations on the frame come here
#     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Display the resulting frame
    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture('videos/vtest.mp4')

while(cap.isOpened()):
    ret, frame = cap.read()
    try:
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        cv2.imshow('frame',gray)
    except:
        break
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
# Open a video with cv2.VideoCapture
vid = cv2.VideoCapture("datasets/videos/car.mp4")

# Grab a frame
ret, frame = vid.read()

# Video
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %%
# Get the properties of video using get() method
print("Frame width: %d" % vid.get(cv2.CAP_PROP_FRAME_WIDTH))
print("Frame height: %d" % vid.get(cv2.CAP_PROP_FRAME_HEIGHT))
print("FPS: %d" % vid.get(cv2.CAP_PROP_FPS))
# Out:
# Frame width: 600
# Frame height: 400
# FPS: 20

# %%
cap = cv2.VideoCapture('datasets/videos/vtest.mp4')

while(cap.isOpened()):
    ret, frame = cap.read()
    try:
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        cv2.imshow('frame',gray)
    except:
        break
    if cv2.waitKey(20) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture('datasets/videos/vtest.mp4')

kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(3,3))
fgbg = cv2.createBackgroundSubtractorMOG2()

while(1):
    
    try:
        ret, frame = cap.read()

        fgmask = fgbg.apply(frame)
        fgmask = cv2.morphologyEx(fgmask, cv2.MORPH_OPEN, kernel)

        cv2.imshow('frame',fgmask)
    except:
        break
    k = cv2.waitKey(30) & 0xff
    if k == 27:
        break

cap.release()
cv2.destroyAllWindows()

# %%
x = np.linspace(0,10,1000)
error = np.random.normal(0,10,1000)
y = 1.5*x+0.7*x**2 + 3*np.sin(x)

# x = x+np.random.normal(0,0.,1000)
y = y+np.random.normal(0,3,1000)

# %%
plt.errorbar(x[::5],y[::5],yerr=error[::5])
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
np.save('sample_data',np.c_[x,y,error])
