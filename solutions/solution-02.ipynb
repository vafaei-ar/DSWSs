# %%
# %matplotlib inline

import numpy as np
import pylab as plt

# %% [markdown]
# ### Question 1

# %% [markdown]
# ### Question 2

# %% [markdown]
# ### Question 3

# %% [markdown]
# ### Question 4
